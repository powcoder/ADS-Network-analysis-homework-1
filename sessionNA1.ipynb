# %% [markdown]
# # NYU CUSP: Applied Data Science, Network Analysis module, session 1
# # Network visualization and basic analysis

# %%
#add necessary libraries
import networkx as nx #library supporting networks
import matplotlib.pyplot as plt #plotting
#make sure plots are embedded into the notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# first let's explore the data structure for the network provided by networkx

# %%
#create an empty undirected network
G=nx.Graph()
#add a node
G.add_node(1)
#add several nodes
G.add_nodes_from([2,3,4])
#we can add not only numbers but also text (or any other python object) as a node 
G.add_node('A')
#now add an edge
G.add_edge(1,2)
#and a set of edges
G.add_edges_from([(1,3),(1,4),(3,4),('A',3),('A',4)])

# %%
#now let's see what we've done
print(G.nodes())
print(G.edges())
# Out:
# [1, 2, 3, 4, 'A']
# [(1, 2), (1, 3), (1, 4), (3, 4), (3, 'A'), (4, 'A')]

# %%
np.random.seed(2011) #fix the origin of random generator - see below why
#now let's visualize, which turns out to be fairly simple with networkx
nx.draw(G,with_labels=True)
# Out:
# /Users/stanislav/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# note that the locations are selected by random - this is why we fixed random generator to make sure appearance is always the same. But what if we have the locations of the nodes we want the python to stick to?

# %%
#set up the location for our nodes
pos={1:(50,50),2:(25,50),3:(75,75),4:(75,25),'A':(100,50)}
#visualize for fixed node locations
nx.draw(G,pos=pos,with_labels=True)

# %% [markdown]
# But networkx does not only allow to store and visualize the networks. It can also perform a lot of useful computations for us, including some network properties. Let's do node degrees for example

# %%
dict(G.degree())
# Out:
# {1: 3, 2: 1, 3: 3, 4: 3, 'A': 2}

# %%
list(dict(G.degree()).values())
# Out:
# [3, 1, 3, 3, 2]

# %%
#let's now use node degrees as sizes of the nodes visualized
nx.draw(G,pos=pos,node_size=50*np.array(list(dict(G.degree()).values()))**2,with_labels=True)

# %% [markdown]
# networkx can also handle directed networks as well

# %%
G2=nx.DiGraph() #create a directed graph
#add same edges as before; notice that when we add edges nodes are added automatically
G2.add_edges_from([(1,2),(1,3),(1,4),(3,4),(4,3),('A',3),('A',4)])

# %%
#visualize the network showing directions
nx.draw(G2,pos=pos,with_labels=True,arrows=True)
# Out:
# /Users/stanislav/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
#calculate incoming and outgoing degrees
print(G2.in_degree())
print(G2.out_degree())
# Out:
# [(1, 0), (2, 1), (3, 3), (4, 3), ('A', 0)]
# [(1, 3), (2, 0), (3, 1), (4, 1), ('A', 2)]

# %% [markdown]
# we can also handle a weighted network

# %%
G3=nx.DiGraph() #create a directed graph
#add same edges as before but with weights
G3.add_weighted_edges_from([(1,2,2),(1,3,2),(1,4,2),(3,4,1),('A',3,3),('A',4,3)])
#we can also add separate edges in the following way
G3.add_edge('A',1,weight=5)

# %%
#we can access all the edges outgoing from a node 'A' like
print(G3['A'])
#a specific edge like
G3['A'][1]['weight']=3
G3['A'][1]['distance']=3
print(G3['A'][1])
#and modify its properties like
# Out:
# {3: {'weight': 3}, 4: {'weight': 3}, 1: {'weight': 5}}
# {'weight': 3, 'distance': 3}

# %%
print(G3['A'])
# Out:
# {3: {'weight': 3}, 4: {'weight': 3}, 1: {'weight': 3, 'distance': 3}}

# %%
G3.edges(data=False)
# Out:
# OutEdgeView([(1, 2), (1, 3), (1, 4), (3, 4), ('A', 3), ('A', 4), ('A', 1)])

# %%
#now let's extract all the edge weights into a list (in the same order as edges go)
w=[d['weight'] for (u,v,d) in G3.edges(data=True)]
print(w)
# Out:
# [2, 2, 2, 1, 3, 3, 3]

# %%
#and visualize the network using edge weights for the edge thikness
nx.draw(G3,pos=pos,with_labels=True,arrows=True,width=3*w,node_size=500)

# %% [markdown]
# ### Excercise 1.
# Visualize the star-like network with 6 nodes located around the circle and one in the center, being connected with the other 6 (all links directed from the center to the outer nodes). Center node should be marked as "C", while others - 1,2,3,4,5,6.

# %% [markdown]
# ## Network of air connections
#
# Now we'll visualize a real-world network of the world airports with direct air connections. File citiesTable.csv is the table of airports together with their lat-long coordinates, while citiesToCities.csv contains the connection data

# %%
import numpy as np
import pandas as pd

# %%
cities = pd.read_csv( 'data/citiesTable.csv' , index_col=0 )
cities.head()
# Out:
#              country name most active airport  long. most active airport  \
# city name
# London     United Kingdom            Heathrow                     -0.103
# Chicago     United States  Chicago Ohare Intl                    -87.842
# Paris              France   Charles De Gaulle                      2.916
# Moscow             Russia          Domododevo                     38.510
# Shanghai            China              Pudong                    122.342
#
#            lat. most active airport  number of routes  \
# city name
# London                       51.795              1984
# Chicago                      42.631              1406
# Paris                        49.021              1254
# Moscow                       55.681              1179
# Shanghai                     31.238              1115
#
#            number incoming flights  number outcoming flights  \
# city name
# London                         993                       992
# Chicago                        705                       702
# Paris                          626                       629
# Moscow                         589                       591
# Shanghai                       560                       556
#
#            number incoming domestic flights  \
# city name
# London                                   57
# Chicago                                 526
# Paris                                    68
# Moscow                                  231
# Shanghai                                357
#
#            number outcoming domestic flights  \
# city name
# London                                    57
# Chicago                                  523
# Paris                                     68
# Moscow                                   231
# Shanghai                                 353
#
#            number incoming international flights  \
# city name
# London                                       936
# Chicago                                      179
# Paris                                        558
# Moscow                                       358
# Shanghai                                     203
#
#            number outcoming international flights  only domestic flights  \
# city name
# London                                        934                      0
# Chicago                                       178                      0
# Paris                                         560                      0
# Moscow                                        359                      0
# Shanghai                                      202                      0
#
#            average distance  max. distance
# city name
# London                 3228          11153
# Chicago                2328          12416
# Paris                  3367          11652
# Moscow                 2772          10054
# Shanghai               2235          12245

# %%
#create a network with city names as nodes
Flights=nx.Graph()
Flights.add_nodes_from(cities.index)

# %%
#create a dictionary of city locations
CityPos={c:(cities['long. most active airport'][c],cities['lat. most active airport'][c])
         for c in cities.index}

# %%
CityPos
# Out:
# {'London': (-0.10300000000000001, 51.795),
#  'Chicago': (-87.84200000000001, 42.631),
#  'Paris': (2.9160000000000004, 49.021),
#  'Moscow': (38.51, 55.681000000000004),
#  'Shanghai': (122.34200000000001, 31.238000000000003),
#  'Beijing': (116.97399999999999, 40.133),
#  'Denver': (-104.456, 40.436),
#  'Los Angeles': (-118.014, 34.57),
#  'New York': (-73.632, 41.066),
#  'Frankfurt': (8.905, 50.044),
#  'Houston': (-94.90299999999999, 30.64),
#  'Washington': (-77.094, 39.574),
#  'Newark': (-73.615, 41.153999999999996),
#  'Tokyo': (140.643, 36.274),
#  'Amsterdam': (5.273, 52.513999999999996),
#  'Madrid': (-3.278, 40.821999999999996),
#  'Seoul': (126.75, 37.781),
#  'Istanbul': (29.357, 41.628),
#  'Singapore': (104.65700000000001, 1.5830000000000002),
#  'Bangkok': (101.245, 14.135),
#  'Atlanta': (-84.04700000000001, 34.061),
#  'Rome': (12.417, 42.34),
#  'San Francisco': (-121.959, 38.031),
#  'Barcelona': (2.13, 41.495),
#  'Munich': (12.31, 48.589),
#  'Toronto': (-79.385, 44.128),
#  'Hong Kong': (114.524, 22.514),
#  'Dubai': (55.607, 25.421),
#  'Guangzhou': (113.49700000000001, 23.654),
#  'Dallas-fort Worth': (-96.397, 33.494),
#  'Sao Paulo': (-46.11600000000001, -23.054000000000002),
#  'Delhi': (77.171, 28.944000000000003),
#  'Brussels': (4.8069999999999995, 51.501999999999995),
#  'Taipei': (121.38799999999999, 25.129),
#  'Kuala Lumpur': (102.18299999999999, 3.242),
#  'Miami': (-79.818, 26.322),
#  'Chengdu': (104.57799999999999, 30.964000000000002),
#  'Vienna': (16.949, 48.183),
#  'Charlotte': (-80.906, 35.356),
#  'Zurich': (8.915, 47.773999999999994),
#  'Manchester': (-1.7919999999999998, 53.589),
#  'Mexico City': (-98.454, 19.727),
#  'St. Petersburg': (30.436999999999998, 60.333),
#  'Duesseldorf': (7.277, 51.482),
#  'Las Vegas': (-114.588, 36.133),
#  'Copenhagen': (13.093, 56.028999999999996),
#  'Minneapolis': (-92.70299999999999, 45.468999999999994),
#  'Bombay': (73.446, 19.147000000000002),
#  'Stockholm': (18.531, 60.086000000000006),
#  'Shenzhen': (114.351, 23.065),
#  'Orlando': (-80.84899999999999, 28.715),
#  'Phoenix': (-111.353, 33.723),
#  'Philadelphia': (-74.736, 40.453),
#  'Milano': (9.213, 46.051),
#  'Kunming': (103.23899999999999, 25.653000000000002),
#  'Berlin': (13.479000000000001, 52.931999999999995),
#  'Chongqing': (107.069, 30.198),
#  'Detroit': (-82.92299999999999, 42.354),
#  'Seattle': (-121.84899999999999, 47.748000000000005),
#  'Manila': (121.03200000000001, 14.847000000000001),
#  "Xi'an": (109.25200000000001, 34.745),
#  'Boston': (-70.342, 42.607),
#  'Abu Dhabi': (55.085, 24.721),
#  'Montreal': (-73.569, 45.784),
#  'Hangzhou': (120.72399999999999, 30.381999999999998),
#  'Sydney': (151.295, -33.911),
#  'Tenerife': (-16.288, 28.074),
#  'Fort Lauderdale': (-79.58800000000001, 26.12),
#  'Xiamen': (118.212, 24.906),
#  'Osaka': (135.406, 34.724000000000004),
#  'Lisbon': (-8.56, 39.302),
#  'Rio De Janeiro': (-42.74, -22.682),
#  'Vancouver': (-122.641, 49.323),
#  'Changcha': (113.366, 28.315),
#  'Gran Canaria': (-14.978, 28.553),
#  'Johannesburg': (28.41, -25.566),
#  'Athens': (24.574, 38.56),
#  'Bogota': (-73.579, 5.169),
#  'Wuhan': (114.346, 31.305999999999997),
#  'Helsinki': (25.605, 60.528),
#  'Kiev': (31.491, 50.575),
#  'Doha': (51.941, 25.435),
#  'Jeddah': (39.26, 22.131999999999998),
#  'Nanjing': (119.436, 32.236),
#  'San Jose': (122.555, 11.276),
#  'Buenos Aires': (-58.227, -34.704),
#  'Prague': (14.433, 50.168),
#  'Nairobi': (37.545, -0.866),
#  'Cancun': (-86.796, 21.06),
#  'Cairo': (31.675, 30.203000000000003),
#  'Qingdao': (120.624, 36.443000000000005),
#  'Portland': (-122.33, 45.981),
#  'Oslo': (11.167, 60.323),
#  'Dublin': (-5.784, 53.702),
#  'Riyadh': (47.163999999999994, 25.596),
#  'Geneva': (6.181, 46.396),
#  'Cleveland': (-81.75, 41.68600000000001),
#  'Birmingham': (-86.59, 33.938),
#  'Jakarta': (107.09299999999999, -5.542999999999999),
#  'Honolulu': (-157.871, 21.531),
#  'Urumqi': (87.79, 44.511),
#  'Melbourne': (145.405, -37.455999999999996),
#  'Lyon': (5.151, 46.21),
#  'Salt Lake City': (-111.963, 41.313),
#  'Sanya': (109.68700000000001, 18.504),
#  'Warsaw': (21.611, 52.276),
#  'Dalian': (121.897, 39.609),
#  'Brasilia': (-47.865, -15.786),
#  'Jinan': (117.359, 37.428000000000004),
#  'Budapest': (19.425, 47.728),
#  'Calgary': (-113.368, 51.18899999999999),
#  'Brisbane': (153.195, -26.974),
#  'Belo Horizonte': (-43.949, -19.39),
#  'Amman': (36.655, 32.204),
#  'Malaga': (-4.166, 37.124),
#  'Stuttgart': (9.369, 49.148999999999994),
#  'Zhengzhou': (114.40100000000001, 34.866),
#  'Hamburg': (10.647, 54.05),
#  'Auckland': (175.31900000000002, -36.347),
#  'Haikou': (110.764, 20.558000000000003),
#  'Santiago': (-70.64399999999999, -32.989000000000004),
#  'Bucharest': (26.17, 44.953),
#  'Lima': (-76.524, -11.37),
#  'Baltimore': (-76.44800000000001, 39.292),
#  'Kuwait': (48.614, 29.377),
#  'Shenyang': (123.48299999999999, 41.637),
#  'Tel-aviv': (35.477, 32.018),
#  'Panama City': (-78.973, 9.118),
#  'Tianjin': (117.57600000000001, 39.207),
#  'Bahrain': (51.056000000000004, 26.451),
#  'Tampa': (-82.223, 28.625),
#  'Casablanca': (-7.317, 33.611999999999995),
#  'Las Palmas': (-13.343, 29.575),
#  'Addis Ababa': (39.332, 9.629),
#  'Ho Chi Minh City': (107.086, 11.364),
#  'Marseille': (5.356, 43.725),
#  'Harbin': (126.417, 46.038999999999994),
#  'Calcutta': (88.744, 23.090999999999998),
#  'Edinburgh': (-2.955, 56.583),
#  'Madras': (80.3, 13.657),
#  'Guiyang': (107.334, 26.897),
#  'Fuerteventura': (-13.773, 28.754),
#  'Muscat': (58.474, 23.988000000000003),
#  'Hyderabad': (78.779, 17.755),
#  'Taiyuan': (113.04700000000001, 38.244),
#  'Nanning': (108.287, 23.013),
#  'Bangalore': (78.113, 13.583),
#  'Fuzhou': (120.105, 26.558000000000003),
#  'San Juan': (-65.337, 18.732),
#  'Nice': (7.359, 44.097),
#  'St. Louis': (-89.95100000000001, 39.247),
#  'Alicante': (-0.264, 38.47),
#  'Sverdlovsk': (61.336999999999996, 57.238),
#  'Palma de Mallorca': (3.2119999999999997, 39.922),
#  'San Diego': (-116.65, 33.222),
#  'Riga': (24.618000000000002, 57.538999999999994),
#  'Nagoya': (137.342, 35.43),
#  'Caracas': (-66.985, 11.005),
#  'Cologne': (7.237, 51.443000000000005),
#  'Valencia': (-67.881, 10.249),
#  'Memphis': (-89.962, 35.07),
#  'Tashkent': (69.468, 41.428999999999995),
#  'Nanchang': (116.5, 29.441),
#  'Hanoi': (106.345, 21.368000000000002),
#  'Busan': (129.563, 35.299),
#  'Algier': (3.359, 37.150999999999996),
#  'Ottawa': (-75.449, 45.537),
#  'Kansas City': (-94.524, 39.496),
#  'Dammam': (50.32899999999999, 26.785),
#  'Beirut': (35.813, 34.368),
#  'Milwaukee': (-87.82799999999999, 43.578),
#  'Sharjah': (55.861000000000004, 25.546999999999997),
#  'Fukuoka': (130.751, 33.976),
#  'Colombo': (80.473, 7.301),
#  'Bristol': (-2.532, 51.637),
#  'Edmonton': (-113.3, 53.516000000000005),
#  'Porto': (-8.469, 41.413000000000004),
#  'Guadalajara': (-102.852, 20.869),
#  'Salvador': (-37.885999999999996, -12.852),
#  'Larnaca': (34.041, 35.458),
#  'Tunis': (10.378, 37.418),
#  'Gothenborg': (12.466, 58.104),
#  'Perth': (116.611, -31.901),
#  'Ninbo': (121.76899999999999, 30.377),
#  'Glasgow': (-4.056, 56.453),
#  'Cincinnati': (-84.447, 39.080999999999996),
#  'Sofia': (23.676, 43.158),
#  'Wenzhou': (121.42, 28.52),
#  'Bergamo': (10.173, 46.123000000000005),
#  'Porto Alegre': (-50.62, -29.991),
#  'Denpasar': (115.27799999999999, -8.581),
#  'Teheran': (51.522, 36.148),
#  'Damascus': (36.857, 33.684),
#  'Guilin': (110.065, 25.363000000000003),
#  'Sapporo': (142.153, 43.292),
#  'Bologna': (11.481, 44.891999999999996),
#  'Karachi': (67.267, 25.51),
#  'Novosibirsk': (83.084, 55.021),
#  'Nashville': (-86.464, 36.207),
#  'Tehran': (51.0, 35.0),
#  'Malta': (14.795, 36.429),
#  'Venice': (12.585999999999999, 45.842),
#  'Curitiba': (-48.626999999999995, -25.215),
#  'Nassau': (-77.111, 25.064),
#  'Milan': (9.461, 45.74100000000001),
#  'Raleigh-durham': (-78.646, 36.461999999999996),
#  'Macau': (113.985, 22.249000000000002),
#  'Yerevan': (44.659, 40.245),
#  'Changchun': (125.2, 43.902),
#  'Toulouse': (1.6059999999999999, 44.048),
#  'Beograd': (20.515, 45.364),
#  'Puerto Vallarta': (-104.757, 21.133000000000003),
#  'Alma-ata': (77.067, 43.586000000000006),
#  'Hefei': (117.49700000000001, 32.3),
#  'San Salvador': (-88.427, 13.734000000000002),
#  'New Orleans': (-89.764, 30.655),
#  'Kahului': (-156.05100000000002, 21.497),
#  'Mytilini': (26.997, 39.094),
#  'Tiruchirappalli': (79.182, 11.275),
#  'Port Blair': (93.21600000000001, 12.068),
#  'Udaipur': (74.493, 25.029),
#  'Guayana': (-62.601000000000006, 8.48),
#  'Trabzon': (40.316, 41.658),
#  'Sao Vicente Island': (-24.425, 17.389),
#  'Volgograd': (44.575, 49.303999999999995),
#  'Chongju': (127.831, 37.194),
#  'Heho': (97.32, 21.245),
#  'Calama': (-68.84, -22.164),
#  'Syktyvkar': (51.408, 62.078),
#  'Split': (16.496, 43.898),
#  'Orenburg': (55.761, 52.326),
#  'Nadym': (73.164, 65.801),
#  'Barranquilla': (-74.635, 11.482000000000001),
#  'Hailar': (120.375, 49.341),
#  'Samarkand': (67.639, 40.167),
#  'Friedrichshafen': (9.852, 48.118),
#  'Caticlan': (122.588, 12.535),
#  'Bacolod': (123.54899999999999, 11.07),
#  'Kodiak': (-152.157, 58.248999999999995),
#  'Visby': (18.577, 58.104),
#  'La Serena': (-70.666, -29.861),
#  'Ilulissat': (-50.419, 69.39),
#  'Ambon': (128.148, -3.5180000000000002),
#  'Bauru': (-48.448, -21.596999999999998),
#  'Ust Kamenogorsk': (82.823, 50.06100000000001),
#  'Idaho Falls': (-111.45200000000001, 43.857),
#  'Qiqihar': (124.53, 47.398999999999994),
#  'Prince George': (-122.465, 54.482),
#  'Blagoveschensk': (127.68700000000001, 50.708),
#  'Norman Wells': (-126.664, 65.469),
#  'Chesterfield Inlet': (-90.552, 63.578),
#  'Nicoya': (-85.755, 10.592),
#  'Panama': (-79.26, 9.622),
#  'Toamasina': (49.653999999999996, -17.516),
#  'Mahajanga': (46.586000000000006, -15.446),
#  'Pemba': (40.87, -12.978),
#  'Nampula': (39.469, -14.51),
#  'Thimphu': (89.70700000000001, 27.671),
#  'Akita': (140.364, 40.025),
#  'Varginha': (-45.123000000000005, -21.316999999999997),
#  'Juiz De Fora': (-42.978, -21.653000000000002),
#  'Passo Fundo': (-51.878, -27.74),
#  ...}

# %%
#visualize all the world airport cities
plt.figure(figsize = (12,6))
nx.draw(Flights,pos=CityPos,with_labels=False,arrows=False,node_size=25)

# %%
#now read the links
links = pd.read_csv( 'data/citiesToCities.csv' , index_col=None )
links.head()
# Out:
#    departure city  long. departure (decimal)  lat. departure (decimal)  \
# 0       Sao Paulo                    -46.116                   -23.054
# 1  Rio De Janeiro                    -42.740                   -22.682
# 2         Beijing                    116.974                    40.133
# 3    Johannesburg                     28.410                   -25.566
# 4        Honolulu                   -157.871                    21.531
#
#   departure country    arrival city  long. departure (decimal).1  \
# 0            Brazil  Rio De Janeiro                      -42.740
# 1            Brazil       Sao Paulo                      -46.116
# 2             China        Shanghai                      122.342
# 3      South Africa       Cape Town                       19.002
# 4     United States           Tokyo                      140.643
#
#    lat. departure (decimal).1 arrival country  number of routes  distance
# 0                     -22.682          Brazil                18       348
# 1                     -23.054          Brazil                18       348
# 2                      31.238           China                18      1100
# 3                     -33.942    South Africa                16      1299
# 4                      36.274           Japan                16      6103

# %%
#create list of edges as tuples
EN=len(links.index)
edgelist=[(links['departure city'][j],links['arrival city'][j]) for j in range(EN)]
edgelist
# Out:
# [('Sao Paulo', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Sao Paulo'),
#  ('Beijing', 'Shanghai'),
#  ('Johannesburg', 'Cape Town'),
#  ('Honolulu', 'Tokyo'),
#  ('Tokyo', 'Honolulu'),
#  ('Tokyo', 'Seoul'),
#  ('Seoul', 'Tokyo'),
#  ('Tokyo', 'Los Angeles'),
#  ('Los Angeles', 'Tokyo'),
#  ('Shanghai', 'Beijing'),
#  ('Hong Kong', 'Bangkok'),
#  ('Bangkok', 'Hong Kong'),
#  ('Taipei', 'Shanghai'),
#  ('Shanghai', 'Taipei'),
#  ('Cape Town', 'Johannesburg'),
#  ('Kigali', 'Entebbe'),
#  ('Shanghai', 'Hong Kong'),
#  ('Hong Kong', 'Shanghai'),
#  ('Muscat', 'Abu Dhabi'),
#  ('New York', 'London'),
#  ('Abu Dhabi', 'Muscat'),
#  ('Shenzhen', 'Shanghai'),
#  ('Shanghai', 'Shenzhen'),
#  ('Taipei', 'Tokyo'),
#  ('Tokyo', 'Taipei'),
#  ('Sao Paulo', 'Belo Horizonte'),
#  ('New York', 'Washington'),
#  ('Washington', 'New York'),
#  ('Qingdao', 'Shanghai'),
#  ('Shanghai', 'Qingdao'),
#  ('Shanghai', 'Chongqing'),
#  ('Chongqing', 'Shanghai'),
#  ('Singapore', 'Jakarta'),
#  ('Jakarta', 'Singapore'),
#  ('Sydney', 'Melbourne'),
#  ('Beijing', 'Tokyo'),
#  ('Tokyo', 'Beijing'),
#  ('London', 'Geneva'),
#  ('Geneva', 'London'),
#  ('Sao Paulo', 'Buenos Aires'),
#  ('Buenos Aires', 'Sao Paulo'),
#  ('Singapore', 'Tokyo'),
#  ('Tokyo', 'Singapore'),
#  ('Chicago', 'New York'),
#  ('New York', 'Chicago'),
#  ('Sao Paulo', 'Brasilia'),
#  ('Bahrain', 'Doha'),
#  ('London', 'Frankfurt'),
#  ("Xi'an", 'Shanghai'),
#  ('Shanghai', "Xi'an"),
#  ('Moscow', 'St. Petersburg'),
#  ('Shanghai', 'Chengdu'),
#  ('Chengdu', 'Shanghai'),
#  ('Quito', 'Guayaquil'),
#  ('Belo Horizonte', 'Sao Paulo'),
#  ('Brasilia', 'Sao Paulo'),
#  ('Tenerife', 'London'),
#  ('London', 'Tenerife'),
#  ('Seoul', 'Shanghai'),
#  ('Tokyo', 'Hong Kong'),
#  ('Hong Kong', 'Tokyo'),
#  ('Shanghai', 'Tokyo'),
#  ('Tokyo', 'Shanghai'),
#  ('London', 'Belfast'),
#  ('Belfast', 'London'),
#  ('Malaga', 'London'),
#  ('London', 'Stockholm'),
#  ('Stockholm', 'London'),
#  ('Auckland', 'Sydney'),
#  ('Madrid', 'London'),
#  ('London', 'Madrid'),
#  ('Moscow', 'Krasnodar'),
#  ('London', 'Edinburgh'),
#  ('London', 'Amsterdam'),
#  ('Krasnodar', 'Moscow'),
#  ('Edinburgh', 'London'),
#  ('Jakarta', 'Kuala Lumpur'),
#  ('Amsterdam', 'London'),
#  ('Kigali', 'Nairobi'),
#  ('Zurich', 'London'),
#  ('London', 'Zurich'),
#  ('Frankfurt', 'London'),
#  ('Chicago', 'Washington'),
#  ('Chicago', 'Paris'),
#  ('London', 'New York'),
#  ('Los Angeles', 'San Francisco'),
#  ('Los Angeles', 'New York'),
#  ('Doha', 'Bahrain'),
#  ('Paris', 'Chicago'),
#  ('Chicago', 'London'),
#  ('London', 'Chicago'),
#  ('London', 'Los Angeles'),
#  ('Los Angeles', 'London'),
#  ('Sanya', 'Shanghai'),
#  ('Shanghai', 'Kunming'),
#  ('Shanghai', 'Guangzhou'),
#  ('Shanghai', 'Sanya'),
#  ('Shanghai', 'Macau'),
#  ('Macau', 'Shanghai'),
#  ('Kunming', 'Shanghai'),
#  ('Guangzhou', 'Shanghai'),
#  ('Osaka', 'Tokyo'),
#  ('Tokyo', 'Osaka'),
#  ('Osaka', 'Seoul'),
#  ('Seoul', 'Bangkok'),
#  ('Seoul', 'Osaka'),
#  ('Bangkok', 'Seoul'),
#  ('St. Petersburg', 'Moscow'),
#  ('Singapore', 'Kuala Lumpur'),
#  ('Singapore', 'Hong Kong'),
#  ('Kuala Lumpur', 'Singapore'),
#  ('Hong Kong', 'Singapore'),
#  ('Shanghai', 'Seoul'),
#  ('Tokyo', 'Bangkok'),
#  ('Melbourne', 'Sydney'),
#  ('Bangkok', 'Tokyo'),
#  ('Guangzhou', 'Bangkok'),
#  ('Bangkok', 'Guangzhou'),
#  ('Tokyo', 'Sapporo'),
#  ('Sapporo', 'Tokyo'),
#  ('London', 'Aberdeen'),
#  ('London', 'Barcelona'),
#  ('London', 'Malaga'),
#  ('Barcelona', 'London'),
#  ('Aberdeen', 'London'),
#  ('Sydney', 'Auckland'),
#  ('Kuala Lumpur', 'Bangkok'),
#  ('Bangkok', 'Kuala Lumpur'),
#  ('London', 'Dublin'),
#  ('Kuala Lumpur', 'Jakarta'),
#  ('Rio De Janeiro', 'Belo Horizonte'),
#  ('Belo Horizonte', 'Rio De Janeiro'),
#  ('Bujumbura', 'Nairobi'),
#  ('Munich', 'London'),
#  ('London', 'Munich'),
#  ('Calgary', 'London'),
#  ('Sydney', 'Los Angeles'),
#  ('San Francisco', 'Los Angeles'),
#  ('Paris', 'Newark'),
#  ('Chicago', 'Los Angeles'),
#  ('Minneapolis', 'Chicago'),
#  ('London', 'Calgary'),
#  ('London', 'Newark'),
#  ('Los Angeles', 'Sydney'),
#  ('Las Vegas', 'Los Angeles'),
#  ('Honolulu', 'Los Angeles'),
#  ('Newark', 'Paris'),
#  ('Newark', 'London'),
#  ('Washington', 'Chicago'),
#  ('Curitiba', 'Sao Paulo'),
#  ('Auckland', 'Melbourne'),
#  ('San Francisco', 'London'),
#  ('London', 'San Francisco'),
#  ('Nanning', 'Shanghai'),
#  ('Delhi', 'Calcutta'),
#  ('Calcutta', 'Delhi'),
#  ('Urumqi', "Xi'an"),
#  ('Singapore', 'Bangkok'),
#  ('Bangkok', 'Singapore'),
#  ('Ouagadougou', 'Cotonou'),
#  ('Cotonou', 'Ouagadougou'),
#  ('Singapore', 'Denpasar'),
#  ('Denpasar', 'Singapore'),
#  ('Sao Paulo', 'Curitiba'),
#  ('London', 'Las Palmas'),
#  ('London', 'Alicante'),
#  ('Alicante', 'London'),
#  ('Las Palmas', 'London'),
#  ('Istanbul', 'Tehran'),
#  ('Tehran', 'Istanbul'),
#  ('Sao Paulo', 'Porto Alegre'),
#  ('Denver', 'Washington'),
#  ('Washington', 'Denver'),
#  ("Xi'an", 'Hangzhou'),
#  ('Beijing', 'Urumqi'),
#  ('Beijing', 'Seoul'),
#  ('Beijing', 'Guangzhou'),
#  ('Seoul', 'Beijing'),
#  ('Sharm El Sheikh', 'London'),
#  ('London', 'Sharm El Sheikh'),
#  ('Okinawa', 'Tokyo'),
#  ('Singapore', 'Brisbane'),
#  ('London', 'Manchester'),
#  ('London', 'Copenhagen'),
#  ('Copenhagen', 'London'),
#  ('Brisbane', 'Singapore'),
#  ('Washington', 'Boston'),
#  ('Boston', 'Washington'),
#  ('Portland', 'Chicago'),
#  ('San Francisco', 'Seoul'),
#  ('Seoul', 'San Francisco'),
#  ('Kuwait', 'Bahrain'),
#  ('Dublin', 'London'),
#  ('Bahrain', 'Kuwait'),
#  ('Vitoria', 'Rio De Janeiro'),
#  ('Montreal', 'Toronto'),
#  ('Toronto', 'Montreal'),
#  ('Tenerife', 'Gran Canaria'),
#  ('Palma de Mallorca', 'Barcelona'),
#  ('Gran Canaria', 'Tenerife'),
#  ('Barcelona', 'Palma de Mallorca'),
#  ('Toronto', 'London'),
#  ('Vancouver', 'London'),
#  ('St. Louis', 'Chicago'),
#  ('San Jose', 'Los Angeles'),
#  ('San Francisco', 'Seattle'),
#  ('San Francisco', 'Chicago'),
#  ('San Francisco', 'New York'),
#  ('Chicago', 'St. Louis'),
#  ('Chicago', 'Minneapolis'),
#  ('Chicago', 'Detroit'),
#  ('Chicago', 'Boston'),
#  ('Mexico City', 'Los Angeles'),
#  ('Melbourne', 'Auckland'),
#  ('London', 'Toronto'),
#  ('London', 'Vancouver'),
#  ('London', 'Boston'),
#  ('Los Angeles', 'San Jose'),
#  ('Los Angeles', 'Chicago'),
#  ('Los Angeles', 'Mexico City'),
#  ('Los Angeles', 'Honolulu'),
#  ('New York', 'San Francisco'),
#  ('New York', 'Los Angeles'),
#  ('Detroit', 'Chicago'),
#  ('Boston', 'Chicago'),
#  ('Boston', 'London'),
#  ('London', 'Larnaca'),
#  ('Larnaca', 'London'),
#  ('San Francisco', 'Hong Kong'),
#  ('London', 'Washington'),
#  ('Washington', 'London'),
#  ('Hong Kong', 'San Francisco'),
#  ('Douala', 'Bangui'),
#  ('Bangui', 'Douala'),
#  ('Xiamen', 'Shanghai'),
#  ('Tianjin', 'Shanghai'),
#  ('Shenyang', 'Shanghai'),
#  ('Shanghai', 'Tianjin'),
#  ('Shanghai', 'Changcha'),
#  ('Shanghai', 'Xiamen'),
#  ('Shanghai', 'Shenyang'),
#  ('Shanghai', 'Nanning'),
#  ('Guiyang', 'Shanghai'),
#  ('Ufa', 'Moscow'),
#  ('Moscow', 'Kiev'),
#  ('Kiev', 'Moscow'),
#  ('Seoul', 'Cheju'),
#  ('Cheju', 'Seoul'),
#  ('Delhi', 'Bombay'),
#  ('Delhi', 'Bangalore'),
#  ('Bombay', 'Delhi'),
#  ('Bombay', 'Ahmedabad'),
#  ('Bangalore', 'Delhi'),
#  ("Xi'an", 'Urumqi'),
#  ('Wuhan', 'Chongqing'),
#  ('Beijing', 'Chengdu'),
#  ('Kunming', 'Chengdu'),
#  ('Chengdu', 'Beijing'),
#  ('Chengdu', 'Kunming'),
#  ('Chongqing', 'Wuhan'),
#  ('Chongqing', 'Guangzhou'),
#  ('Guangzhou', 'Chongqing'),
#  ('Sapporo', 'Osaka'),
#  ('Dar Es Salaam', 'Nairobi'),
#  ('Sao Paulo', 'Salvador'),
#  ('Sao Paulo', 'Florianopolis'),
#  ('Cuiaba', 'Sao Paulo'),
#  ('Tenerife', 'Manchester'),
#  ('Manchester', 'Tenerife'),
#  ('London', 'Gran Canaria'),
#  ('Gran Canaria', 'London'),
#  ('Ho Chi Minh City', 'Bangkok'),
#  ('Bangkok', 'Ho Chi Minh City'),
#  ('Okinawa', 'Osaka'),
#  ('Osaka', 'Okinawa'),
#  ('Dubai', 'Muscat'),
#  ('Monrovia', 'Accra'),
#  ('Porto Alegre', 'Sao Paulo'),
#  ('Accra', 'Monrovia'),
#  ('Sydney', 'Christchurch'),
#  ('Christchurch', 'Sydney'),
#  ('Shanghai', 'Wuhan'),
#  ('Kahului', 'Kona'),
#  ('Washington', 'Charleston'),
#  ('Washington', 'Atlanta'),
#  ('Honolulu', 'Molokai'),
#  ('Atlanta', 'Washington'),
#  ('Xiamen', 'Beijing'),
#  ('Xiamen', 'Hefei'),
#  ('Urumqi', 'Beijing'),
#  ('Qingdao', 'Harbin'),
#  ('Shanghai', 'Nanchang'),
#  ('Beijing', 'Xiamen'),
#  ('Beijing', 'Lanzhou'),
#  ('Beijing', 'Hangzhou'),
#  ('Beijing', 'Dalian'),
#  ('Beijing', 'Changcha'),
#  ('Beijing', 'Changchun'),
#  ('Lanzhou', 'Beijing'),
#  ('Kunming', 'Hangzhou'),
#  ('Nanchang', 'Shanghai'),
#  ('Hong Kong', 'Hangzhou'),
#  ('Hangzhou', "Xi'an"),
#  ('Hangzhou', 'Beijing'),
#  ('Hangzhou', 'Hong Kong'),
#  ('Hangzhou', 'Guangzhou'),
#  ('Hefei', 'Xiamen'),
#  ('Dalian', 'Beijing'),
#  ('Changcha', 'Beijing'),
#  ('Changchun', 'Beijing'),
#  ('Guangzhou', 'Beijing'),
#  ('Guangzhou', 'Hangzhou'),
#  ('Busan', 'Seoul'),
#  ('Seoul', 'Busan'),
#  ('Haikou', 'Changcha'),
#  ('Changcha', 'Haikou'),
#  ('Malta', 'London'),
#  ('London', 'Malta'),
#  ('Kilimanjaro', 'Mombasa'),
#  ('Entebbe', 'Kigali'),
#  ('Tokyo', 'Okinawa'),
#  ('Sydney', 'Bangkok'),
#  ('Nice', 'London'),
#  ('Manchester', 'London'),
#  ('Lisbon', 'London'),
#  ('London', 'Lisbon'),
#  ('London', 'Dubai'),
#  ('London', 'Nice'),
#  ('London', 'Glasgow'),
#  ('London', 'Faro'),
#  ('Johannesburg', 'Durban'),
#  ('Glasgow', 'London'),
#  ('Faro', 'London'),
#  ('Dubai', 'London'),
#  ('Durban', 'Johannesburg'),
#  ('Bangkok', 'Sydney'),
#  ('Washington', 'Orlando'),
#  ('Tenerife', 'Madrid'),
#  ('Moscow', 'Khabarovsk'),
#  ('Madrid', 'Tenerife'),
#  ('Khabarovsk', 'Moscow'),
#  ('Rome', 'London'),
#  ('Portland', 'New York'),
#  ('Chicago', 'Portland'),
#  ('New York', 'Portland'),
#  ('Auckland', 'Brisbane'),
#  ('Madrid', 'Lisbon'),
#  ('Madrid', 'Amsterdam'),
#  ('Lisbon', 'Madrid'),
#  ('Sverdlovsk', 'Moscow'),
#  ('Moscow', 'Sverdlovsk'),
#  ('Moscow', 'Novosibirsk'),
#  ('Moscow', 'Omsk'),
#  ('Moscow', 'Krasnoyarsk'),
#  ('Novosibirsk', 'Moscow'),
#  ('Omsk', 'Moscow'),
#  ('Madrid', 'Paris'),
#  ('Krasnoyarsk', 'Moscow'),
#  ('New York', 'Frankfurt'),
#  ('Frankfurt', 'New York'),
#  ('Paris', 'Madrid'),
#  ('Sochi', 'Moscow'),
#  ('Rio De Janeiro', 'Porto Alegre'),
#  ('Montreal', 'Paris'),
#  ('Santiago', 'Buenos Aires'),
#  ('Luanda', 'Kinshasa'),
#  ('Kinshasa', 'Douala'),
#  ('Kinshasa', 'Brussels'),
#  ('Buenos Aires', 'Santiago'),
#  ('Douala', 'Kinshasa'),
#  ('Conakry', 'Banjul'),
#  ('Paris', 'Montreal'),
#  ('Brussels', 'Luanda'),
#  ('Brussels', 'Kigali'),
#  ('Banjul', 'Conakry'),
#  ('Barcelona', 'Ibiza'),
#  ('Abidjan', 'Lome'),
#  ('Berlin', 'London'),
#  ('Palma de Mallorca', 'Madrid'),
#  ('Paris', 'London'),
#  ('London', 'Berlin'),
#  ('London', 'Paris'),
#  ('Toronto', 'Chicago'),
#  ('Toronto', 'New York'),
#  ('Vancouver', 'Los Angeles'),
#  ('Montreal', 'New York'),
#  ('Taipei', 'Los Angeles'),
#  ('Salvador', 'Recife'),
#  ('Sacramento', 'Los Angeles'),
#  ('San Francisco', 'Tokyo'),
#  ('Seattle', 'San Francisco'),
#  ('Seattle', 'Los Angeles'),
#  ('Seattle', 'Denver'),
#  ('Santiago', 'Lima'),
#  ('San Diego', 'Chicago'),
#  ('Palm Springs', 'San Francisco'),
#  ('Chicago', 'Tampa'),
#  ('Chicago', 'San Francisco'),
#  ('Chicago', 'Seattle'),
#  ('Chicago', 'Orlando'),
#  ('Chicago', 'Fort Lauderdale'),
#  ('Chicago', 'Atlanta'),
#  ('Kahului', 'Los Angeles'),
#  ('Tokyo', 'New York'),
#  ('Miami', 'London'),
#  ('Orlando', 'Chicago'),
#  ('London', 'Montreal'),
#  ('London', 'Miami'),
#  ('London', 'Houston'),
#  ('London', 'Atlanta'),
#  ('Los Angeles', 'Vancouver'),
#  ('Los Angeles', 'Taipei'),
#  ('Los Angeles', 'Sacramento'),
#  ('Los Angeles', 'Seattle'),
#  ('Los Angeles', 'Kahului'),
#  ('Los Angeles', 'Las Vegas'),
#  ('Los Angeles', 'Kona'),
#  ('Los Angeles', 'Washington'),
#  ('Los Angeles', 'Guadalajara'),
#  ('Los Angeles', 'Dallas-fort Worth'),
#  ('Los Angeles', 'Denver'),
#  ('Los Angeles', 'Boston'),
#  ('Los Angeles', 'Auckland'),
#  ('Las Vegas', 'Chicago'),
#  ('New York', 'Toronto'),
#  ('New York', 'Montreal'),
#  ('New York', 'Tokyo'),
#  ('New York', 'Paris'),
#  ('Houston', 'London'),
#  ('Washington', 'Los Angeles'),
#  ('Tokyo', 'San Francisco'),
#  ('Guadalajara', 'Los Angeles'),
#  ('Frankfurt', 'Dallas-fort Worth'),
#  ('Dallas-fort Worth', 'Los Angeles'),
#  ('Dallas-fort Worth', 'Frankfurt'),
#  ('Denver', 'Seattle'),
#  ('Denver', 'Los Angeles'),
#  ('Boston', 'Los Angeles'),
#  ('Atlanta', 'Chicago'),
#  ('Atlanta', 'London'),
#  ('Port Hartcourt', 'Abuja'),
#  ('Abuja', 'Port Hartcourt'),
#  ('Shanghai', 'Guiyang'),
#  ('Shanghai', 'Guilin'),
#  ('Shanghai', 'Haikou'),
#  ('Guilin', 'Shanghai'),
#  ('Haikou', 'Shanghai'),
#  ('Changcha', 'Shanghai'),
#  ('Istanbul', 'Izmir'),
#  ('Izmir', 'Istanbul'),
#  ('Kunming', 'Changcha'),
#  ('Changcha', 'Kunming'),
#  ('Mineralnye Vody', 'Moscow'),
#  ('Moscow', 'Ufa'),
#  ('Tokyo', 'Fukuoka'),
#  ('Fukuoka', 'Tokyo'),
#  ('Kathmandu', 'Delhi'),
#  ('Jammu', 'Delhi'),
#  ('Guwahati', 'Delhi'),
#  ('Delhi', 'Kathmandu'),
#  ('Delhi', 'Jammu'),
#  ('Delhi', 'Guwahati'),
#  ('Bombay', 'Bangalore'),
#  ('Bangalore', 'Madras'),
#  ('Bangalore', 'Bombay'),
#  ('Ahmedabad', 'Bombay'),
#  ('Zanzibar', 'Dar Es Salaam'),
#  ('Nairobi', 'Dar Es Salaam'),
#  ('Moscow', 'Berlin'),
#  ('Berlin', 'Moscow'),
#  ('Jeddah', 'Dubai'),
#  ('Dubai', 'Jeddah'),
#  ("Xi'an", 'Lanzhou'),
#  ("Xi'an", 'Yinchuan'),
#  ('Urumqi', 'Kashi'),
#  ('Jinan', 'Dalian'),
#  ('Beijing', 'Chongqing'),
#  ('Lanzhou', "Xi'an"),
#  ('Kashi', 'Urumqi'),
#  ('Yinchuan', "Xi'an"),
#  ('Hangzhou', 'Chongqing'),
#  ('Chengdu', 'Changcha'),
#  ('Chengdu', 'Guangzhou'),
#  ('Changcha', 'Chengdu'),
#  ('Chongqing', 'Beijing'),
#  ('Chongqing', 'Hangzhou'),
#  ('Guangzhou', 'Chengdu'),
#  ('Taipei', 'Singapore'),
#  ('Singapore', 'Taipei'),
#  ('Singapore', 'Manila'),
#  ('Manila', 'Singapore'),
#  ('Guayaquil', 'Quito'),
#  ('Ouagadougou', 'Niamey'),
#  ('Niamey', 'Ouagadougou'),
#  ('Douala', 'Cotonou'),
#  ('Cotonou', 'Douala'),
#  ('Kazan', 'Moscow'),
#  ('Kaliningrad', 'Moscow'),
#  ('Moscow', 'Kazan'),
#  ('Osaka', 'Sapporo'),
#  ('Seoul', 'Fukuoka'),
#  ('Fukuoka', 'Seoul'),
#  ('Lisbon', 'Barcelona'),
#  ('Barcelona', 'Madrid'),
#  ('Barcelona', 'Lisbon'),
#  ('Kahului', 'Molokai'),
#  ('Molokai', 'Honolulu'),
#  ('Kona', 'Kahului'),
#  ('Salvador', 'Sao Paulo'),
#  ('Londrina', 'Sao Paulo'),
#  ('Goiania', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Goiania'),
#  ('Rio De Janeiro', 'Curitiba'),
#  ('Rio De Janeiro', 'Brasilia'),
#  ('Florianopolis', 'Sao Paulo'),
#  ('Curitiba', 'Rio De Janeiro'),
#  ('Sao Paulo', 'Uberlandia'),
#  ('Sao Paulo', 'Londrina'),
#  ('Sao Paulo', 'Cuiaba'),
#  ('Brasilia', 'Rio De Janeiro'),
#  ('Vienna', 'Moscow'),
#  ('Moscow', 'Vienna'),
#  ('Santiago', 'Madrid'),
#  ('Manchester', 'Alicante'),
#  ('Barcelona', 'Tenerife'),
#  ('Alicante', 'Manchester'),
#  ('Kuwait', 'Dubai'),
#  ('Dubai', 'Kuwait'),
#  ('Colombo', 'Male'),
#  ('Phoenix', 'Minneapolis'),
#  ('Wellington', 'Sydney'),
#  ('Phuket', 'Bangkok'),
#  ('Chiang Mai', 'Bangkok'),
#  ('Bangkok', 'Chiang Mai'),
#  ('Moscow', 'Rostov'),
#  ('Wuhan', 'Shanghai'),
#  ('Urumqi', 'Shanghai'),
#  ('Shanghai', 'Urumqi'),
#  ('Shanghai', 'Zhengzhou'),
#  ('Zhengzhou', 'Shanghai'),
#  ('Salt Lake City', 'Denver'),
#  ('Chicago', 'Charleston'),
#  ('Chicago', 'Amsterdam'),
#  ('Minneapolis', 'Denver'),
#  ('Washington', 'Portland'),
#  ('Washington', 'Detroit'),
#  ('Freeport', 'Fort Lauderdale'),
#  ('Freetown', 'Banjul'),
#  ('Fort Lauderdale', 'Freeport'),
#  ('Detroit', 'Denver'),
#  ('Denver', 'Salt Lake City'),
#  ('Denver', 'Minneapolis'),
#  ('Denver', 'Detroit'),
#  ('Denver', 'Atlanta'),
#  ('Charleston', 'Chicago'),
#  ('Charleston', 'Washington'),
#  ('Banjul', 'Freetown'),
#  ('Amsterdam', 'Chicago'),
#  ('Accra', 'Lome'),
#  ('Houston', 'Denver'),
#  ('Houston', 'Washington'),
#  ('Washington', 'Houston'),
#  ('Surabaya', 'Singapore'),
#  ('Singapore', 'Surabaya'),
#  ('Los Angeles', 'Guatemala City'),
#  ('Guatemala City', 'Los Angeles'),
#  ('Brisbane', 'Auckland'),
#  ('Yantai', 'Shanghai'),
#  ('Xiamen', 'Shenzhen'),
#  ('Xiamen', 'Nanjing'),
#  ('Xiamen', 'Zhengzhou'),
#  ("Xi'an", 'Beijing'),
#  ("Xi'an", 'Nanjing'),
#  ("Xi'an", 'Nanchang'),
#  ("Xi'an", 'Changcha'),
#  ('Wuhan', 'Beijing'),
#  ('Wenzhou', 'Shanghai'),
#  ('Wenzhou', 'Guangzhou'),
#  ('Qingdao', 'Guangzhou'),
#  ('Shenzhen', 'Hangzhou'),
#  ('Sanya', 'Hangzhou'),
#  ('Sanya', 'Zhengzhou'),
#  ('Shanghai', 'Yantai'),
#  ('Shanghai', 'Huhhot'),
#  ('San Francisco', 'Denver'),
#  ('Shanghai', 'Wenzhou'),
#  ('Shanghai', 'Nagoya'),
#  ('Beijing', "Xi'an"),
#  ('Beijing', 'Wuhan'),
#  ('Beijing', 'Nanjing'),
#  ('Beijing', 'Yinchuan'),
#  ('Beijing', 'Harbin'),
#  ('Beijing', 'Hong Kong'),
#  ('Tokyo', 'Guangzhou'),
#  ('Nanjing', 'Xiamen'),
#  ('Nanjing', "Xi'an"),
#  ('Nanjing', 'Beijing'),
#  ('Nanjing', 'Haikou'),
#  ('Nanjing', 'Guangzhou'),
#  ('Nagoya', 'Shanghai'),
#  ('Nanchang', "Xi'an"),
#  ('Yinchuan', 'Beijing'),
#  ('Harbin', 'Qingdao'),
#  ('Harbin', 'Beijing'),
#  ('Harbin', 'Hangzhou'),
#  ('Harbin', 'Dalian'),
#  ('Hong Kong', 'Beijing'),
#  ('Hangzhou', 'Shenzhen'),
#  ('Hangzhou', 'Sanya'),
#  ('Hangzhou', 'Kunming'),
#  ('Hangzhou', 'Harbin'),
#  ('Huhhot', 'Shanghai'),
#  ('Haikou', 'Nanjing'),
#  ('Dalian', 'Harbin'),
#  ('Denver', 'San Francisco'),
#  ('Changcha', "Xi'an"),
#  ('Zhengzhou', 'Xiamen'),
#  ('Zhengzhou', 'Sanya'),
#  ('Guangzhou', 'Wenzhou'),
#  ('Guangzhou', 'Qingdao'),
#  ('Guangzhou', 'Tokyo'),
#  ('Guangzhou', 'Nanjing'),
#  ('Taipei', 'Seoul'),
#  ('Seoul', 'Taipei'),
#  ('Tianjin', 'Hangzhou'),
#  ('Sanya', 'Changcha'),
#  ('Nanjing', 'Changcha'),
#  ('Hangzhou', 'Tianjin'),
#  ('Hangzhou', 'Changcha'),
#  ('Changcha', 'Sanya'),
#  ('Changcha', 'Nanjing'),
#  ('Changcha', 'Hangzhou'),
#  ('Entebbe', 'Addis Ababa'),
#  ('Addis Ababa', 'Entebbe'),
#  ('Singapore', 'Melbourne'),
#  ('Singapore', 'Frankfurt'),
#  ('Melbourne', 'Singapore'),
#  ('London', 'Budapest'),
#  ('Frankfurt', 'Singapore'),
#  ('Durban', 'Cape Town'),
#  ('Cape Town', 'Durban'),
#  ('Budapest', 'London'),
#  ('San Francisco', 'Boston'),
#  ('Orlando', 'Washington'),
#  ('New York', 'Denver'),
#  ('Denver', 'New York'),
#  ('Denver', 'Boston'),
#  ('Boston', 'Denver'),
#  ('Vladivostok', 'Moscow'),
#  ('Tenerife', 'Barcelona'),
#  ('Moscow', 'Vladivostok'),
#  ('Milano', 'Rome'),
#  ('Madrid', 'Gran Canaria'),
#  ('Gran Canaria', 'Barcelona'),
#  ('Rome', 'Milano'),
#  ('Barcelona', 'Gran Canaria'),
#  ('Rio De Janeiro', 'Buenos Aires'),
#  ('Buenos Aires', 'Rio De Janeiro'),
#  ('Amsterdam', 'Madrid'),
#  ('Penang', 'Kuala Lumpur'),
#  ('Moscow', 'Samara'),
#  ('Moscow', 'Irkutsk'),
#  ('Moscow', 'Sochi'),
#  ('Lisbon', 'Paris'),
#  ('Milan', 'Paris'),
#  ('Irkutsk', 'Moscow'),
#  ('Houston', 'Paris'),
#  ('Washington', 'Paris'),
#  ('Rome', 'Paris'),
#  ('Paris', 'Lisbon'),
#  ('Paris', 'Milan'),
#  ('Paris', 'Houston'),
#  ('Paris', 'Washington'),
#  ('Paris', 'Rome'),
#  ('Paris', 'Barcelona'),
#  ('Barcelona', 'Paris'),
#  ('Campinas', 'Belo Horizonte'),
#  ('Salvador', 'Rio De Janeiro'),
#  ('Porto Alegre', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Vitoria'),
#  ('Belo Horizonte', 'Campinas'),
#  ('Belo Horizonte', 'Porto Seguro'),
#  ('Porto Seguro', 'Sao Paulo'),
#  ('Vancouver', 'Calgary'),
#  ('Monrovia', 'Abidjan'),
#  ('Ouagadougou', 'Brussels'),
#  ('Nairobi', 'Brussels'),
#  ('Lome', 'Brussels'),
#  ('Jeddah', 'Riyadh'),
#  ('Ibiza', 'Barcelona'),
#  ('Entebbe', 'Brussels'),
#  ('Douala', 'Brussels'),
#  ('Brussels', 'Monrovia'),
#  ('Brussels', 'Ouagadougou'),
#  ('Brussels', 'Douala'),
#  ('Brussels', 'Bujumbura'),
#  ('Brussels', 'Banjul'),
#  ('Brussels', 'Abidjan'),
#  ('Banjul', 'Brussels'),
#  ('Abidjan', 'Brussels'),
#  ('Valencia', 'Palma de Mallorca'),
#  ('Vienna', 'Barcelona'),
#  ('Salzburg', 'London'),
#  ('London', 'Duesseldorf'),
#  ('Palma de Mallorca', 'Valencia'),
#  ('Munich', 'Istanbul'),
#  ('Madrid', 'Palma de Mallorca'),
#  ('London', 'Hamburg'),
#  ('London', 'Basel-Mulhouse-Freiburg'),
#  ('London', 'Salzburg'),
#  ('Hamburg', 'London'),
#  ('Frankfurt', 'Vienna'),
#  ('Duesseldorf', 'London'),
#  ('Basel-Mulhouse-Freiburg', 'London'),
#  ('Barcelona', 'Vienna'),
#  ('Montreal', 'London'),
#  ('Taipei', 'San Francisco'),
#  ('Tampa', 'Chicago'),
#  ('Santa Ana', 'Chicago'),
#  ('Salt Lake City', 'Chicago'),
#  ('Salt Lake City', 'Los Angeles'),
#  ('Springfield', 'Chicago'),
#  ('San Francisco', 'Taipei'),
#  ('San Francisco', 'Palm Springs'),
#  ('San Francisco', 'Portland'),
#  ('Seattle', 'Chicago'),
#  ('San Diego', 'Los Angeles'),
#  ('Fort Myers', 'Chicago'),
#  ('Raleigh-durham', 'New York'),
#  ('Phoenix', 'Portland'),
#  ('Phoenix', 'Los Angeles'),
#  ('Philadelphia', 'Chicago'),
#  ('Portland', 'San Francisco'),
#  ('Portland', 'Phoenix'),
#  ('Portland', 'Los Angeles'),
#  ('Chicago', 'Toronto'),
#  ('Chicago', 'Springfield'),
#  ('Chicago', 'San Antonio'),
#  ('Chicago', 'San Diego'),
#  ('Chicago', 'Fort Myers'),
#  ('Chicago', 'Tokyo'),
#  ('Chicago', 'Mexico City'),
#  ('Chicago', 'Las Vegas'),
#  ('Chicago', 'Houston'),
#  ('Chicago', 'Dallas-fort Worth'),
#  ('Chicago', 'Denver'),
#  ('Tokyo', 'Chicago'),
#  ('New Orleans', 'Chicago'),
#  ('Miami', 'Paris'),
#  ('Mexico City', 'Chicago'),
#  ('Orlando', 'London'),
#  ('Orlando', 'Los Angeles'),
#  ('Orlando', 'New York'),
#  ('Madrid', 'New York'),
#  ('Lima', 'Santiago'),
#  ('Lihue', 'Los Angeles'),
#  ('London', 'Orlando'),
#  ('New York', 'Charlotte'),
#  ('London', 'Shannon'),
#  ('Los Angeles', 'San Diego'),
#  ('Los Angeles', 'Phoenix'),
#  ('Los Angeles', 'Orlando'),
#  ('Los Angeles', 'Lihue'),
#  ('Los Angeles', 'Albuquerque'),
#  ('Kona', 'Los Angeles'),
#  ('New York', 'Raleigh-durham'),
#  ('New York', 'Orlando'),
#  ('New York', 'Madrid'),
#  ('New York', 'Fort Lauderdale'),
#  ('New York', 'Boston'),
#  ('Houston', 'Chicago'),
#  ('Fort Lauderdale', 'Chicago'),
#  ('Fort Lauderdale', 'New York'),
#  ('Dallas-fort Worth', 'San Francisco'),
#  ('Dallas-fort Worth', 'Denver'),
#  ('Denver', 'Chicago'),
#  ('Denver', 'Dallas-fort Worth'),
#  ('Charlotte', 'New York'),
#  ('Paris', 'Miami'),
#  ('Paris', 'New York'),
#  ('Boston', 'New York'),
#  ('Auckland', 'Los Angeles'),
#  ('Chicago', 'Hong Kong'),
#  ('London', 'Delhi'),
#  ('London', 'Bombay'),
#  ('New York', 'Brussels'),
#  ('Hong Kong', 'Chicago'),
#  ('Delhi', 'London'),
#  ('Brussels', 'New York'),
#  ('Bombay', 'London'),
#  ('Porlamar', 'Caracas'),
#  ('Caracas', 'Porlamar'),
#  ('Zhuhai', 'Shanghai'),
#  ('Shijiazhuang', 'Shanghai'),
#  ('Shenyang', 'Hangzhou'),
#  ('Shanghai', 'Shijiazhuang'),
#  ('Shanghai', 'Fuzhou'),
#  ('Shanghai', 'Zhuhai'),
#  ('Hangzhou', 'Shenyang'),
#  ('Fuzhou', 'Shanghai'),
#  ('Shenyang', 'Zhengzhou'),
#  ('Kunming', 'Jinghong'),
#  ('Jinghong', 'Kunming'),
#  ('Zhengzhou', 'Shenyang'),
#  ('Moscow', 'Mineralnye Vody'),
#  ('Nagoya', 'Seoul'),
#  ('Seoul', 'Hong Kong'),
#  ('Hong Kong', 'Seoul'),
#  ('Seoul', 'Nagoya'),
#  ('Srinagar', 'Jammu'),
#  ('Srinagar', 'Delhi'),
#  ('Singapore', 'Bombay'),
#  ('Pune', 'Delhi'),
#  ('Patina', 'Delhi'),
#  ('Madras', 'Delhi'),
#  ('Madras', 'Bangalore'),
#  ('Lucknow', 'Delhi'),
#  ('Jammu', 'Srinagar'),
#  ('Hyderabad', 'Delhi'),
#  ('Hyderabad', 'Bombay'),
#  ('Goa', 'Bombay'),
#  ('Delhi', 'Srinagar'),
#  ('Delhi', 'Pune'),
#  ('Delhi', 'Madras'),
#  ('Delhi', 'Lucknow'),
#  ('Delhi', 'Hyderabad'),
#  ('Delhi', 'Bangkok'),
#  ('Delhi', 'Ahmedabad'),
#  ('Kochi', 'Bombay'),
#  ('Bombay', 'Singapore'),
#  ('Bombay', 'Hyderabad'),
#  ('Bombay', 'Goa'),
#  ('Bombay', 'Kochi'),
#  ('Bombay', 'Bangkok'),
#  ('Bangkok', 'Delhi'),
#  ('Bangkok', 'Bombay'),
#  ('Ahmedabad', 'Delhi'),
#  ('Montevideo', 'Buenos Aires'),
#  ('Buenos Aires', 'Montevideo'),
#  ('Vladivostok', 'Khabarovsk'),
#  ('Khabarovsk', 'Vladivostok'),
#  ('Trinidad', 'Santa Cruz'),
#  ('Seoul', 'Cebu'),
#  ('Cebu', 'Seoul'),
#  ('Nairobi', 'Mombasa'),
#  ('Dar Es Salaam', 'Zanzibar'),
#  ('Nicoya', 'San Jose'),
#  ('San Jose', 'Nicoya'),
#  ('Xining', "Xi'an"),
#  ('Xiamen', 'Kunming'),
#  ('Xiamen', 'Changcha'),
#  ("Xi'an", 'Xining'),
#  ("Xi'an", 'Chengdu'),
#  ("Xi'an", 'Chongqing'),
#  ('Wuhan', 'Nanning'),
#  ('Wuhan', 'Chengdu'),
#  ('Urumqi', 'Chengdu'),
#  ('Urumqi', 'Chongqing'),
#  ('Jinan', 'Harbin'),
#  ('Jinan', 'Chengdu'),
#  ('Shenzhen', 'Chengdu'),
#  ('Sanya', 'Chengdu'),
#  ('Nanning', 'Wuhan'),
#  ('Nanjing', 'Chongqing'),
#  ('Lhasa', 'Chongqing'),
#  ('Guiyang', 'Kunming'),
#  ('Kunming', 'Xiamen'),
#  ('Kunming', 'Guiyang'),
#  ('Kunming', 'Chongqing'),
#  ('Harbin', 'Jinan'),
#  ('Hong Kong', 'Chengdu'),
#  ('Dalian', 'Jinan'),
#  ('Chengdu', "Xi'an"),
#  ('Chengdu', 'Wuhan'),
#  ('Chengdu', 'Urumqi'),
#  ('Chengdu', 'Jinan'),
#  ('Chengdu', 'Shenzhen'),
#  ('Chengdu', 'Sanya'),
#  ('Chengdu', 'Hong Kong'),
#  ('Changcha', 'Xiamen'),
#  ('Changcha', 'Chongqing'),
#  ('Chongqing', "Xi'an"),
#  ('Chongqing', 'Urumqi'),
#  ('Chongqing', 'Nanjing'),
#  ('Chongqing', 'Lhasa'),
#  ('Chongqing', 'Kunming'),
#  ('Chongqing', 'Changcha'),
#  ('Taipei', 'Osaka'),
#  ('Singapore', 'Ho Chi Minh City'),
#  ('Singapore', 'Perth'),
#  ('Singapore', 'Penang'),
#  ('Ho Chi Minh City', 'Singapore'),
#  ('Perth', 'Singapore'),
#  ('Penang', 'Singapore'),
#  ('Osaka', 'Taipei'),
#  ('Moscow', 'Kaliningrad'),
#  ('Moscow', 'Chelyabinsk'),
#  ('Chelyabinsk', 'Moscow'),
#  ('Sharm El Sheikh', 'Manchester'),
#  ('Manchester', 'Sharm El Sheikh'),
#  ('Moscow', 'Odessa'),
#  ('Odessa', 'Moscow'),
#  ('Paris', 'Porto'),
#  ('Porto', 'Paris'),
#  ('San Jose', 'Phoenix'),
#  ('Phoenix', 'San Jose'),
#  ('Khartoum', 'Jeddah'),
#  ('Jeddah', 'Khartoum'),
#  ('Osh', 'Moscow'),
#  ('Moscow', 'Osh'),
#  ('Douala', 'Libreville'),
#  ('Milano', 'Barcelona'),
#  ('Madrid', 'Moscow'),
#  ('Madrid', 'Barcelona'),
#  ('Moscow', 'Madrid'),
#  ('Moscow', 'Barcelona'),
#  ('Barcelona', 'Milano'),
#  ('Barcelona', 'Moscow'),
#  ('Khabarovsk', 'Magadan'),
#  ('Magadan', 'Khabarovsk'),
#  ('Barcelona', 'Amsterdam'),
#  ('Amsterdam', 'Barcelona'),
#  ('Molokai', 'Kahului'),
#  ('Lanai', 'Honolulu'),
#  ('Honolulu', 'Kahului'),
#  ('Salvador', 'Brasilia'),
#  ('Salvador', 'Aracaju'),
#  ('Sao Luis', 'Belem'),
#  ('Porto Velho', 'Cuiaba'),
#  ('Goiania', 'Cuiaba'),
#  ('Florianopolis', 'Porto Alegre'),
#  ('Campo Grande', 'Sao Paulo'),
#  ('Sao Paulo', 'Campo Grande'),
#  ('Cuiaba', 'Goiania'),
#  ('Brasilia', 'Salvador'),
#  ('Belem', 'Sao Luis'),
#  ('Belem', 'Maraba'),
#  ('Aracaju', 'Salvador'),
#  ('Tenerife', 'East Midlands'),
#  ('Sevilla', 'Barcelona'),
#  ('London', 'Grenoble'),
#  ('Santiago', 'Barcelona'),
#  ('Porto', 'Madrid'),
#  ('Madrid', 'Porto'),
#  ('London', 'Fuerteventura'),
#  ('Grenoble', 'London'),
#  ('Fuerteventura', 'London'),
#  ('East Midlands', 'Tenerife'),
#  ('Barcelona', 'Sevilla'),
#  ('Barcelona', 'Santiago'),
#  ('Barcelona', 'Malaga'),
#  ('Malaga', 'Manchester'),
#  ('Malaga', 'Barcelona'),
#  ('Taiyuan', 'Shanghai'),
#  ('Shanghai', 'Taiyuan'),
#  ('Shanghai', 'Bangkok'),
#  ('Bangkok', 'Shanghai'),
#  ('Ko Samui', 'Singapore'),
#  ('Singapore', 'Ko Samui'),
#  ('Hanoi', 'Bangkok'),
#  ('Bangkok', 'Hanoi'),
#  ('Amman', 'Abu Dhabi'),
#  ('Milano', 'Brussels'),
#  ('Brussels', 'Milano'),
#  ('Male', 'Colombo'),
#  ('Muscat', 'Dubai'),
#  ('Karachi', 'Dubai'),
#  ('Dubai', 'Karachi'),
#  ('Jeddah', 'Alexandria'),
#  ('Alexandria', 'Jeddah'),
#  ('Seattle', 'Seoul'),
#  ('Porto Alegre', 'Montevideo'),
#  ('Navegantes', 'Sao Paulo'),
#  ('Minneapolis', 'Phoenix'),
#  ('Los Angeles', 'Seoul'),
#  ('New York', 'Seoul'),
#  ('Seoul', 'Seattle'),
#  ('Seoul', 'Los Angeles'),
#  ('Seoul', 'New York'),
#  ('Goiania', 'Sao Paulo'),
#  ('Brasilia', 'Goiania'),
#  ('Atlanta', 'Denver'),
#  ('Wellington', 'Auckland'),
#  ('Sydney', 'Wellington'),
#  ('Perth', 'Denpasar'),
#  ('Melbourne', 'Wellington'),
#  ('Melbourne', 'Brisbane'),
#  ('Denpasar', 'Perth'),
#  ('Brisbane', 'Melbourne'),
#  ('Dubai', 'Colombo'),
#  ('Colombo', 'Dubai'),
#  ('Chiang Rai', 'Bangkok'),
#  ('Bangkok', 'Phuket'),
#  ('Bangkok', 'Chiang Rai'),
#  ('Rostov', 'Moscow'),
#  ('Xiamen', 'Guangzhou'),
#  ("Xi'an", 'Wuhan'),
#  ('Wuhan', "Xi'an"),
#  ('Wuhan', 'Sanya'),
#  ...]

# %%
#add edges to the network
Flights.add_edges_from(edgelist)

# %%
#visualize the network
plt.figure(figsize = (12,6))
nx.draw(Flights,pos=CityPos,with_labels=False,node_size=15,style='dotted',edge_color='green')
# Out:
# /Users/stanislav/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
#most connected airport
AirportDeg=dict(Flights.degree())
TopAirport=list(AirportDeg.keys())[np.argmax(list(AirportDeg.values()))]
print('Most connected airport is {0} with {1} connections'.format(TopAirport,AirportDeg[TopAirport]))
# Out:
# Most connected airport is London with 311 connections

# %%
#least connected airport
LeastAirport=list(AirportDeg.keys())[np.argmin(list(AirportDeg.values()))]
print('Least connected airport is {0} with {1} connections'.format(LeastAirport,AirportDeg[LeastAirport]))
# Out:
# Least connected airport is Kashi with 1 connections

# %%
#compute network average number of connections per airport and network density
k_avg=mean(list(AirportDeg.values()))
dens=k_avg/(len(Flights)-1)
print('Average number of connections per airport is {0}; network density ={1}'.format(k_avg,dens))
# Out:
# Average number of connections per airport is 10.473895582329318; network density =0.003506493331881258

# %% [markdown]
# ### Excercise 2.
# Create a list of top 20 most connected airports accross the world and visualize them among the rest using a larger size and different color for the top ones. Consider adding labels for the top airports
#
# Hint: Feel free to use width=0 to eliminate edges on the plot. You may plot the entire graph first and then a subgraph (use .subgraph([list of nodes])) of top airports on top; alternatively can use list of sizes and colors but top nodes might be overlayed with others that way; use node_size and node_color to set up size and color of the nodes in draw().
